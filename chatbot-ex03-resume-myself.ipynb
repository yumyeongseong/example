# %% [markdown]
# # [문제] Managing Conversation History
# - trim_messages()
# - RunnablePassthrough
# - itemgetter()
#
# 세션ID 설정하고, 대화를 진행합니다. (multi-turn conversation)
# LLM 모델이 과거 대화를 알지(기억) 못하는 상황을 만드세요.

# %%
## 1. 모듈 import
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_core.prompts import ChatPromptTemplate

## [방법 1]
# from langchain_core.chat_history import BaseChatMessageHistory
# from langchain_core.chat_history import InMemoryChatMessageHistory

## [방법 2]
# from langchain_core.chat_history import BaseChatMessageHistory, InMemoryChatMessageHistory

## [방법 3]
from langchain_core.chat_history import (
    BaseChatMessageHistory, 
    InMemoryChatMessageHistory
)


## 2. .env 파일에서 환경변수 읽어오기
load_dotenv()
# Out:
# True

# %%
## 3. 세션별 대화 히스토리를 저장할 임시 메모리 저장소
## type: dict 
store = {}

## 4. 함수 정의: 세션 ID에 따라 대화 히스토리 반환
def get_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

## 5. prompt template 정의
messages = [
    ('system', '''당신은 이력서 작성 컨설턴트입니다.
아래 정보를 바탕으로 지원자 입장에서 2000자 이내로 이력서를 작성합니다.
문장은 자연스럽고 매끄럽게 작성합니다.'''),
	('placeholder', '{chat_history}'),
	('user', '{query}')
]

prompt = ChatPromptTemplate.from_messages(messages=messages)

# %%
## 6. ChatOpenAI 인스턴스 생성: 모델 생성
llm = ChatOpenAI(
    model='gpt-4o',
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()],
)

# %%
# 7. trim 설정
from langchain_core.messages import trim_messages

trimmer = trim_messages(
    max_tokens= 65,
    strategy='last',
    token_counter=llm,
    include_system=True,
    allow_partial=False,
    start_on='human',
)

# %%
## 8. chain 구성
from langchain_core.runnables import RunnablePassthrough
from operator import itemgetter

chain = (
    RunnablePassthrough.assign(chat_history=itemgetter('chat_history')| trimmer)
    |prompt 
    | llm 
)

chain
# Out:
# RunnableAssign(mapper={
#   chat_history: RunnableLambda(itemgetter('chat_history'))
#                 | RunnableLambda(...)
# })
# | ChatPromptTemplate(input_variables=['query'], optional_variables=['chat_history'], input_types={'chat_history': list[typing.Annotated[typing.Union[typing.Annotated[langchain_core.messages.ai.AIMessage, Tag(tag='ai')], typing.Annotated[langchain_core.messages.human.HumanMessage, Tag(tag='human')], typing.Annotated[langchain_core.messages.chat.ChatMessage, Tag(tag='chat')], typing.Annotated[langchain_core.messages.system.SystemMessage, Tag(tag='system')], typing.Annotated[langchain_core.messages.function.FunctionMessage, Tag(tag='function')], typing.Annotated[langchain_core.messages.tool.ToolMessage, Tag(tag='tool')], typing.Annotated[langchain_core.messages.ai.AIMessageChunk, Tag(tag='AIMessageChunk')], typing.Annotated[langchain_core.messages.human.HumanMessageChunk, Tag(tag='HumanMessageChunk')], typing.Annotated[langchain_core.messages.chat.ChatMessageChunk, Tag(tag='ChatMessageChunk')], typing.Annotated[langchain_core.messages.system.SystemMessageChunk, Tag(tag='SystemMessageChunk')], typing.Annotated[langchain_core.messages.function.FunctionMessageChunk, Tag(tag='FunctionMessageChunk')], typing.Annotated[langchain_core.messages.tool.ToolMessageChunk, Tag(tag='ToolMessageChunk')]], FieldInfo(annotation=NoneType, required=True, discriminator=Discriminator(discriminator=<function _get_type at 0x000002865AE28D30>, custom_error_type=None, custom_error_message=None, custom_error_context=None))]]}, partial_variables={'chat_history': []}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 이력서 작성 컨설턴트입니다.\n아래 정보를 바탕으로 지원자 입장에서 2000자 이내로 이력서를 작성합니다.\n문장은 자연스럽고 매끄럽게 작성합니다.'), additional_kwargs={}), MessagesPlaceholder(variable_name='chat_history', optional=True), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], input_types={}, partial_variables={}, template='{query}'), additional_kwargs={})])
# | ChatOpenAI(callbacks=[<langchain_core.callbacks.streaming_stdout.StreamingStdOutCallbackHandler object at 0x000002865B8D8D90>], client=<openai.resources.chat.completions.completions.Completions object at 0x000002865B8DBEE0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000002865B9980D0>, root_client=<openai.OpenAI object at 0x000002865B8DB9A0>, root_async_client=<openai.AsyncOpenAI object at 0x000002865B8D9780>, model_name='gpt-4o', model_kwargs={}, openai_api_key=SecretStr('**********'), streaming=True)

# %%
## 8. 함수 정의: 대화 이력(히스토리) 인스턴스 리턴

def get_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

# %%
## 8. chain에 대화 히스토리 기능을 래핑해서 추가
with_message_history = RunnableWithMessageHistory(
    chain,
    get_history,
    input_messages_key='query',
    history_messages_key='chat_history'
)

## 9. chain 실행
while True:
    query = input('이력서 작성 컨설턴트입니다. 질문하세요. [종료: S] >>> ')

    if query.upper() == 'S':
        break

    with_message_history.invoke(
        {'query': query},
        config={'configurable': {'session_id': 'resume'}}      
    )
# Out:
# [이력서]
#
# **개인 정보**
# - 이름: 유명성
# - 이메일: ymseong@email.com
# - 전화번호: 010-1234-5678
# - 주소: 서울특별시 강남구
#
# ---
#
# **학력**
#
# - **서울대학교**, 서울특별시
#   경영학 학사
#   2016년 3월 – 2020년 2월
#
# - **서울과학기술고등학교**, 서울특별시
#   졸업
#   2013년 3월 – 2016년 2월
#
# ---
#
# **경력**
#
# - **ABC 마케팅**, 서울특별시
#   마케팅 코디네이터
#   2021년 1월 – 현재
#   - 디지털 마케팅 캠페인 기획 및 실행
#   - SNS 플랫폼을 활용한 브랜드 인지도 제고
#   - 고객 설문조사를 통한 시장 트렌드 분석 및 전략 수립
#
# - **XYZ 컨설팅**, 서울특별시
#   인턴
#   2019년 6월 – 2019년 8월
#   - 프로젝트 관리 및 클라이언트 미팅 지원
#   - 시장 조사 및 데이터 분석 보조
#   - 보고서 작성 및 프레젠테이션 준비 지원
#
# ---
#
# **기술**
#
# - Microsoft Office Suite (Word, Excel, PowerPoint)
# - Adobe Photoshop 및 Illustrator
# - Google Analytics
# - SEO 및 SEM 전략
#
# ---
#
# **언어**
#
# - 한국어: 모국어
# - 영어: 고급 (TOEIC 920점)
#
# ---
#
# **수상 및 인증**
#
# - 서울대학교 총장상 (2019년 우수 학업 성취 및 리더십)
# - Google Analytics 인증 (2021년)
# - 국제마케팅협회 주최 마케팅 아이디어 경진대회 우승 (2020년)
#
# ---
#
# **기타 활동**
#
# - **서울대학교 광고동아리**
#   회장
#   2018년 3월 – 2019년 2월
#   - 동아리 활동 총괄 및 외부 행사 기획
#   - 기업과의 협력 프로젝트 진행
#
# - **봉사활동**, 서울시 청소년 센터
#   멘토
#   2020년 3월 – 2020년 12월
#   - 고등학생 대상 진로 상담 및 학습 지도
#   - 비영리 봉사활동 기획 및 실행
#
# ---
#
# **개인적 성향 및 목표**
#
# 저는 창의적 사고와 분석적 능력을 바탕으로 디지털 마케팅에 강한 열정을 가지고 있습니다. 팀워크를 중요시하며 협업을 통해 더 나은 결과를 도출하는 것을 목표로 합니다. 앞으로도 끊임없는 학습과 성장을 통해 마케팅 전문가로서의 역량을 더욱 발전시키고자 합니다.
#
# (참고: 구체적인 정보를 남기지 않기 위해 일부 정보는 예시로 작성되었습니다.)[이름]
# [주소]
# [전화번호]
# [이메일]
#
# [개인 요약]
# 창의적이고 목표 지향적인 마케팅 및 영업 전문가로서 1년 7개월의 풍부한 경험을 바탕으로 고객 중심의 전략 개발과 실질적인 성과 달성에 기여해왔습니다. 빠르게 변화하는 시장 환경에 적응하고 협업을 통해 최상의 결과를 도출할 수 있는 능력을 갖추고 있습니다.
#
# [경력 요약]
#
# 1. 회사명 (2022년 - 현재)
#    - 직급: 현장 영업 관리자
#    - 주요 업무:
#      - 고객 요구 분석 및 요구사항에 맞춘 맞춤형 서비스 제공
#      - 월간 매출 목표 설정 및 달성을 위한 전략 수립
#      - 신속한 고객 문제 해결을 통해 고객 만족도 향상 및 유지
#      - 경쟁사 분석 및 시장 동향을 모니터링하여 판매 촉진 방안 마련
#
# 2. 회사명 (2021년 - 2022년)
#    - 직급: 마케팅 담당자
#    - 주요 업무:
#      - 제품 출시 및 프로모션 캠페인 기획 및 실행
#      - 디지털 마케팅 채널 관리 및 콘텐츠 생성
#      - 시장 조사 및 데이터 분석을 통한 고객 인사이트 도출
#      - 효과적인 브랜드 메시지 전달을 위한 커뮤니케이션 전략 개발
#
# [학력]
# 대학교명, 전공, 졸업년도
#
# [기술 및 자격증]
# - 데이터 분석 및 보고서 작성 능력
# - 디지털 마케팅 도구 및 소셜 미디어 플랫폼 활용 능력
# - CRM 소프트웨어 경험
#
# [기타 정보]
# - 뛰어난 대인 관계 기술로 팀의 협업을 촉진하고 긍정적인 업무 환경 조성에 기여
# - 고객과의 신뢰 구축을 통해 장기적 비즈니스 관계 유지를 이끌어냄
#
# [결론]
# 실무 경험과 강력한 커뮤니케이션 능력을 바탕으로 고객의 기대를 초과하는 결과를 창출하는 것을 목표로 하고 있습니다. 귀사의 비즈니스 성공에 기여할 기회를 기대합니다.[이름]
# [주소]
# [전화번호]
# [이메일 주소]
#
# ---
#
# **경력 목표**
# 시각적 창의성과 기술적 역량을 결합하여 디지털 미디어 분야에서 혁신적인 콘텐츠를 개발하고자 하는 열정을 가진 인재로, 다양한 멀티미디어 도구와 프로그래밍 언어를 활용한 프로젝트에 참여하고 싶습니다.
#
# **기술 스킬**
#
# - **디지털 비디오 편집 & 이펙트 디자인**: 현재 교육기관에서 Adobe Premiere Pro와 After Effects 과정을 이수 중입니다. 이 두 소프트웨어에 대한 체계적인 학습을 통해 비디오 편집 및 모션 그래픽 디자인 능력을 향상시키고 있으며, 이를 통해 창의적이고 몰입감 있는 콘텐츠 제작에 기여할 수 있습니다.
#
# - **프로그래밍**: Python 언어를 배우면서 기본적인 프로그래밍 원리와 데이터 분석 기법을 익히고 있습니다. 이러한 지식을 통해 효율적인 워크플로우 자동화 및 데이터 기반의 프로젝트를 수행할 준비가 되어 있습니다.
#
# - **웹 개발**: HTML을 활용하여 웹 페이지 구조 설계 및 간단한 웹 애플리케이션 제작에 대한 이해를 높이고 있습니다. 이러한 웹 기술을 영상 및 애니메이션 콘텐츠와 결합하여 사용자 인터페이스를 개선할 수 있는 역량을 갖추고자 합니다.
#
# - **인공지능 및 머신러닝**: LLM(Large Language Model) 학습을 통해 최신 인공지능 기술 동향을 파악하고 있으며, 이를 통해 자연어 처리 및 생성 AI 프로젝트에 대한 관심과 이해도를 높이고 있습니다.
#
# **교육**
# [현재 교육기관 이름] - [시작 연도]부터 수강 중
# - Adobe Premiere Pro 및 After Effects 과정
# - Python 프로그래밍
# - HTML 웹 개발 기초
# - LLM을 활용한 인공지능 및 머신러닝 입문
#
# **프로젝트 및 성과**
# - 다양한 영상을 편집 및 이펙트 디자인하여 학습 프로젝트를 성공적으로 완수함.
# - Python을 사용하여 간단한 데이터 분석 프로젝트에 참여, 데이터 시각화 등의 기본적 역량을 증명함.
#
# **기타 스킬 및 활동**
# - 강한 문제 해결 능력과 창의성을 바탕으로 팀 프로젝트 및 과제에 기여.
# - 디지털 미디어와 기술의 융합에 지속적인 관심을 가지고 자기주도적인 학습 지속.
#
# **언어 능력**
# - 한국어: 모국어
# - 영어: 중급 (읽기 및 작문 능력)
#
# ---
#
# 본인은 현재 교육 과정에서 습득한 기술과 역량을 활용하여 귀사의 비전과 목표를 실현하는 데 기여할 수 있는 기회를 열망하고 있습니다. 감사합니다.

# %%
get_history('resume')
# Out:
# InMemoryChatMessageHistory(messages=[HumanMessage(content='이름:유명성', additional_kwargs={}, response_metadata={}), AIMessage(content='[이력서]\n\n**개인 정보**\n- 이름: 유명성\n- 이메일: ymseong@email.com\n- 전화번호: 010-1234-5678\n- 주소: 서울특별시 강남구\n\n---\n\n**학력**\n\n- **서울대학교**, 서울특별시  \n  경영학 학사  \n  2016년 3월 – 2020년 2월  \n\n- **서울과학기술고등학교**, 서울특별시  \n  졸업  \n  2013년 3월 – 2016년 2월  \n\n---\n\n**경력**\n\n- **ABC 마케팅**, 서울특별시  \n  마케팅 코디네이터  \n  2021년 1월 – 현재  \n  - 디지털 마케팅 캠페인 기획 및 실행\n  - SNS 플랫폼을 활용한 브랜드 인지도 제고\n  - 고객 설문조사를 통한 시장 트렌드 분석 및 전략 수립\n\n- **XYZ 컨설팅**, 서울특별시  \n  인턴  \n  2019년 6월 – 2019년 8월  \n  - 프로젝트 관리 및 클라이언트 미팅 지원\n  - 시장 조사 및 데이터 분석 보조\n  - 보고서 작성 및 프레젠테이션 준비 지원\n\n---\n\n**기술**\n\n- Microsoft Office Suite (Word, Excel, PowerPoint)\n- Adobe Photoshop 및 Illustrator\n- Google Analytics\n- SEO 및 SEM 전략\n\n---\n\n**언어**\n\n- 한국어: 모국어\n- 영어: 고급 (TOEIC 920점)\n\n---\n\n**수상 및 인증**\n\n- 서울대학교 총장상 (2019년 우수 학업 성취 및 리더십)\n- Google Analytics 인증 (2021년)\n- 국제마케팅협회 주최 마케팅 아이디어 경진대회 우승 (2020년)\n\n---\n\n**기타 활동**\n\n- **서울대학교 광고동아리**  \n  회장  \n  2018년 3월 – 2019년 2월\n  - 동아리 활동 총괄 및 외부 행사 기획\n  - 기업과의 협력 프로젝트 진행\n\n- **봉사활동**, 서울시 청소년 센터  \n  멘토  \n  2020년 3월 – 2020년 12월  \n  - 고등학생 대상 진로 상담 및 학습 지도\n  - 비영리 봉사활동 기획 및 실행\n\n---\n\n**개인적 성향 및 목표**\n\n저는 창의적 사고와 분석적 능력을 바탕으로 디지털 마케팅에 강한 열정을 가지고 있습니다. 팀워크를 중요시하며 협업을 통해 더 나은 결과를 도출하는 것을 목표로 합니다. 앞으로도 끊임없는 학습과 성장을 통해 마케팅 전문가로서의 역량을 더욱 발전시키고자 합니다.\n\n(참고: 구체적인 정보를 남기지 않기 위해 일부 정보는 예시로 작성되었습니다.)', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8'}, id='run-f3641606-08e5-4281-948b-620f98060009-0'), HumanMessage(content='경력: 총 1년 7개월 중 1년차 마케팅 업무 2년차 현장 영업', additional_kwargs={}, response_metadata={}), AIMessage(content='[이름]\n[주소]\n[전화번호]\n[이메일]\n\n[개인 요약]\n창의적이고 목표 지향적인 마케팅 및 영업 전문가로서 1년 7개월의 풍부한 경험을 바탕으로 고객 중심의 전략 개발과 실질적인 성과 달성에 기여해왔습니다. 빠르게 변화하는 시장 환경에 적응하고 협업을 통해 최상의 결과를 도출할 수 있는 능력을 갖추고 있습니다. \n\n[경력 요약]\n\n1. 회사명 (2022년 - 현재)\n   - 직급: 현장 영업 관리자\n   - 주요 업무:\n     - 고객 요구 분석 및 요구사항에 맞춘 맞춤형 서비스 제공\n     - 월간 매출 목표 설정 및 달성을 위한 전략 수립\n     - 신속한 고객 문제 해결을 통해 고객 만족도 향상 및 유지\n     - 경쟁사 분석 및 시장 동향을 모니터링하여 판매 촉진 방안 마련\n\n2. 회사명 (2021년 - 2022년)\n   - 직급: 마케팅 담당자\n   - 주요 업무:\n     - 제품 출시 및 프로모션 캠페인 기획 및 실행\n     - 디지털 마케팅 채널 관리 및 콘텐츠 생성\n     - 시장 조사 및 데이터 분석을 통한 고객 인사이트 도출\n     - 효과적인 브랜드 메시지 전달을 위한 커뮤니케이션 전략 개발\n\n[학력]\n대학교명, 전공, 졸업년도\n\n[기술 및 자격증]\n- 데이터 분석 및 보고서 작성 능력\n- 디지털 마케팅 도구 및 소셜 미디어 플랫폼 활용 능력\n- CRM 소프트웨어 경험\n\n[기타 정보]\n- 뛰어난 대인 관계 기술로 팀의 협업을 촉진하고 긍정적인 업무 환경 조성에 기여\n- 고객과의 신뢰 구축을 통해 장기적 비즈니스 관계 유지를 이끌어냄\n\n[결론]\n실무 경험과 강력한 커뮤니케이션 능력을 바탕으로 고객의 기대를 초과하는 결과를 창출하는 것을 목표로 하고 있습니다. 귀사의 비즈니스 성공에 기여할 기회를 기대합니다.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9bddfca6e2'}, id='run-9c2b9034-f64a-47a2-9f86-cee57a95898f-0'), HumanMessage(content='기술: 현재 교육기관에서 프리미어프로, 애프터이펙트, Python, LLM, Html 등 이수중', additional_kwargs={}, response_metadata={}), AIMessage(content='[이름]  \n[주소]  \n[전화번호]  \n[이메일 주소]  \n\n---\n\n**경력 목표**  \n시각적 창의성과 기술적 역량을 결합하여 디지털 미디어 분야에서 혁신적인 콘텐츠를 개발하고자 하는 열정을 가진 인재로, 다양한 멀티미디어 도구와 프로그래밍 언어를 활용한 프로젝트에 참여하고 싶습니다.\n\n**기술 스킬**\n\n- **디지털 비디오 편집 & 이펙트 디자인**: 현재 교육기관에서 Adobe Premiere Pro와 After Effects 과정을 이수 중입니다. 이 두 소프트웨어에 대한 체계적인 학습을 통해 비디오 편집 및 모션 그래픽 디자인 능력을 향상시키고 있으며, 이를 통해 창의적이고 몰입감 있는 콘텐츠 제작에 기여할 수 있습니다.\n\n- **프로그래밍**: Python 언어를 배우면서 기본적인 프로그래밍 원리와 데이터 분석 기법을 익히고 있습니다. 이러한 지식을 통해 효율적인 워크플로우 자동화 및 데이터 기반의 프로젝트를 수행할 준비가 되어 있습니다.\n\n- **웹 개발**: HTML을 활용하여 웹 페이지 구조 설계 및 간단한 웹 애플리케이션 제작에 대한 이해를 높이고 있습니다. 이러한 웹 기술을 영상 및 애니메이션 콘텐츠와 결합하여 사용자 인터페이스를 개선할 수 있는 역량을 갖추고자 합니다.\n\n- **인공지능 및 머신러닝**: LLM(Large Language Model) 학습을 통해 최신 인공지능 기술 동향을 파악하고 있으며, 이를 통해 자연어 처리 및 생성 AI 프로젝트에 대한 관심과 이해도를 높이고 있습니다.\n\n**교육**  \n[현재 교육기관 이름] - [시작 연도]부터 수강 중  \n- Adobe Premiere Pro 및 After Effects 과정  \n- Python 프로그래밍  \n- HTML 웹 개발 기초  \n- LLM을 활용한 인공지능 및 머신러닝 입문\n\n**프로젝트 및 성과**  \n- 다양한 영상을 편집 및 이펙트 디자인하여 학습 프로젝트를 성공적으로 완수함.\n- ...

# %%
for info in get_history('resume').messages:
    print(info.content)
    print('*' * 50)
# Out:
# 이름:유명성
# **************************************************
# [이력서]
#
# **개인 정보**
# - 이름: 유명성
# - 이메일: ymseong@email.com
# - 전화번호: 010-1234-5678
# - 주소: 서울특별시 강남구
#
# ---
#
# **학력**
#
# - **서울대학교**, 서울특별시
#   경영학 학사
#   2016년 3월 – 2020년 2월
#
# - **서울과학기술고등학교**, 서울특별시
#   졸업
#   2013년 3월 – 2016년 2월
#
# ---
#
# **경력**
#
# - **ABC 마케팅**, 서울특별시
#   마케팅 코디네이터
#   2021년 1월 – 현재
#   - 디지털 마케팅 캠페인 기획 및 실행
#   - SNS 플랫폼을 활용한 브랜드 인지도 제고
#   - 고객 설문조사를 통한 시장 트렌드 분석 및 전략 수립
#
# - **XYZ 컨설팅**, 서울특별시
#   인턴
#   2019년 6월 – 2019년 8월
#   - 프로젝트 관리 및 클라이언트 미팅 지원
#   - 시장 조사 및 데이터 분석 보조
#   - 보고서 작성 및 프레젠테이션 준비 지원
#
# ---
#
# **기술**
#
# - Microsoft Office Suite (Word, Excel, PowerPoint)
# - Adobe Photoshop 및 Illustrator
# - Google Analytics
# - SEO 및 SEM 전략
#
# ---
#
# **언어**
#
# - 한국어: 모국어
# - 영어: 고급 (TOEIC 920점)
#
# ---
#
# **수상 및 인증**
#
# - 서울대학교 총장상 (2019년 우수 학업 성취 및 리더십)
# - Google Analytics 인증 (2021년)
# - 국제마케팅협회 주최 마케팅 아이디어 경진대회 우승 (2020년)
#
# ---
#
# **기타 활동**
#
# - **서울대학교 광고동아리**
#   회장
#   2018년 3월 – 2019년 2월
#   - 동아리 활동 총괄 및 외부 행사 기획
#   - 기업과의 협력 프로젝트 진행
#
# - **봉사활동**, 서울시 청소년 센터
#   멘토
#   2020년 3월 – 2020년 12월
#   - 고등학생 대상 진로 상담 및 학습 지도
#   - 비영리 봉사활동 기획 및 실행
#
# ---
#
# **개인적 성향 및 목표**
#
# 저는 창의적 사고와 분석적 능력을 바탕으로 디지털 마케팅에 강한 열정을 가지고 있습니다. 팀워크를 중요시하며 협업을 통해 더 나은 결과를 도출하는 것을 목표로 합니다. 앞으로도 끊임없는 학습과 성장을 통해 마케팅 전문가로서의 역량을 더욱 발전시키고자 합니다.
#
# (참고: 구체적인 정보를 남기지 않기 위해 일부 정보는 예시로 작성되었습니다.)
# **************************************************
# 경력: 총 1년 7개월 중 1년차 마케팅 업무 2년차 현장 영업
# **************************************************
# [이름]
# [주소]
# [전화번호]
# [이메일]
#
# [개인 요약]
# 창의적이고 목표 지향적인 마케팅 및 영업 전문가로서 1년 7개월의 풍부한 경험을 바탕으로 고객 중심의 전략 개발과 실질적인 성과 달성에 기여해왔습니다. 빠르게 변화하는 시장 환경에 적응하고 협업을 통해 최상의 결과를 도출할 수 있는 능력을 갖추고 있습니다.
#
# [경력 요약]
#
# 1. 회사명 (2022년 - 현재)
#    - 직급: 현장 영업 관리자
#    - 주요 업무:
#      - 고객 요구 분석 및 요구사항에 맞춘 맞춤형 서비스 제공
#      - 월간 매출 목표 설정 및 달성을 위한 전략 수립
#      - 신속한 고객 문제 해결을 통해 고객 만족도 향상 및 유지
#      - 경쟁사 분석 및 시장 동향을 모니터링하여 판매 촉진 방안 마련
#
# 2. 회사명 (2021년 - 2022년)
#    - 직급: 마케팅 담당자
#    - 주요 업무:
#      - 제품 출시 및 프로모션 캠페인 기획 및 실행
#      - 디지털 마케팅 채널 관리 및 콘텐츠 생성
#      - 시장 조사 및 데이터 분석을 통한 고객 인사이트 도출
#      - 효과적인 브랜드 메시지 전달을 위한 커뮤니케이션 전략 개발
#
# [학력]
# 대학교명, 전공, 졸업년도
#
# [기술 및 자격증]
# - 데이터 분석 및 보고서 작성 능력
# - 디지털 마케팅 도구 및 소셜 미디어 플랫폼 활용 능력
# - CRM 소프트웨어 경험
#
# [기타 정보]
# - 뛰어난 대인 관계 기술로 팀의 협업을 촉진하고 긍정적인 업무 환경 조성에 기여
# - 고객과의 신뢰 구축을 통해 장기적 비즈니스 관계 유지를 이끌어냄
#
# [결론]
# 실무 경험과 강력한 커뮤니케이션 능력을 바탕으로 고객의 기대를 초과하는 결과를 창출하는 것을 목표로 하고 있습니다. 귀사의 비즈니스 성공에 기여할 기회를 기대합니다.
# **************************************************
# 기술: 현재 교육기관에서 프리미어프로, 애프터이펙트, Python, LLM, Html 등 이수중
# **************************************************
# [이름]
# [주소]
# [전화번호]
# [이메일 주소]
#
# ---
#
# **경력 목표**
# 시각적 창의성과 기술적 역량을 결합하여 디지털 미디어 분야에서 혁신적인 콘텐츠를 개발하고자 하는 열정을 가진 인재로, 다양한 멀티미디어 도구와 프로그래밍 언어를 활용한 프로젝트에 참여하고 싶습니다.
#
# **기술 스킬**
#
# - **디지털 비디오 편집 & 이펙트 디자인**: 현재 교육기관에서 Adobe Premiere Pro와 After Effects 과정을 이수 중입니다. 이 두 소프트웨어에 대한 체계적인 학습을 통해 비디오 편집 및 모션 그래픽 디자인 능력을 향상시키고 있으며, 이를 통해 창의적이고 몰입감 있는 콘텐츠 제작에 기여할 수 있습니다.
#
# - **프로그래밍**: Python 언어를 배우면서 기본적인 프로그래밍 원리와 데이터 분석 기법을 익히고 있습니다. 이러한 지식을 통해 효율적인 워크플로우 자동화 및 데이터 기반의 프로젝트를 수행할 준비가 되어 있습니다.
#
# - **웹 개발**: HTML을 활용하여 웹 페이지 구조 설계 및 간단한 웹 애플리케이션 제작에 대한 이해를 높이고 있습니다. 이러한 웹 기술을 영상 및 애니메이션 콘텐츠와 결합하여 사용자 인터페이스를 개선할 수 있는 역량을 갖추고자 합니다.
#
# - **인공지능 및 머신러닝**: LLM(Large Language Model) 학습을 통해 최신 인공지능 기술 동향을 파악하고 있으며, 이를 통해 자연어 처리 및 생성 AI 프로젝트에 대한 관심과 이해도를 높이고 있습니다.
#
# **교육**
# [현재 교육기관 이름] - [시작 연도]부터 수강 중
# - Adobe Premiere Pro 및 After Effects 과정
# - Python 프로그래밍
# - HTML 웹 개발 기초
# - LLM을 활용한 인공지능 및 머신러닝 입문
#
# **프로젝트 및 성과**
# - 다양한 영상을 편집 및 이펙트 디자인하여 학습 프로젝트를 성공적으로 완수함.
# - Python을 사용하여 간단한 데이터 분석 프로젝트에 참여, 데이터 시각화 등의 기본적 역량을 증명함.
#
# **기타 스킬 및 활동**
# - 강한 문제 해결 능력과 창의성을 바탕으로 팀 프로젝트 및 과제에 기여.
# - 디지털 미디어와 기술의 융합에 지속적인 관심을 가지고 자기주도적인 학습 지속.
#
# **언어 능력**
# - 한국어: 모국어
# - 영어: 중급 (읽기 및 작문 능력)
#
# ---
#
# 본인은 현재 교육 과정에서 습득한 기술과 역량을 활용하여 귀사의 비전과 목표를 실현하는 데 기여할 수 있는 기회를 열망하고 있습니다. 감사합니다.
# **************************************************

# %%
for message in get_history('resume').messages:
    print(f'[{message.type.upper()}]: {message.content}\n')
# Out:
# [HUMAN]: 이름:유명성
#
# [AI]: [이력서]
#
# **개인 정보**
# - 이름: 유명성
# - 이메일: ymseong@email.com
# - 전화번호: 010-1234-5678
# - 주소: 서울특별시 강남구
#
# ---
#
# **학력**
#
# - **서울대학교**, 서울특별시
#   경영학 학사
#   2016년 3월 – 2020년 2월
#
# - **서울과학기술고등학교**, 서울특별시
#   졸업
#   2013년 3월 – 2016년 2월
#
# ---
#
# **경력**
#
# - **ABC 마케팅**, 서울특별시
#   마케팅 코디네이터
#   2021년 1월 – 현재
#   - 디지털 마케팅 캠페인 기획 및 실행
#   - SNS 플랫폼을 활용한 브랜드 인지도 제고
#   - 고객 설문조사를 통한 시장 트렌드 분석 및 전략 수립
#
# - **XYZ 컨설팅**, 서울특별시
#   인턴
#   2019년 6월 – 2019년 8월
#   - 프로젝트 관리 및 클라이언트 미팅 지원
#   - 시장 조사 및 데이터 분석 보조
#   - 보고서 작성 및 프레젠테이션 준비 지원
#
# ---
#
# **기술**
#
# - Microsoft Office Suite (Word, Excel, PowerPoint)
# - Adobe Photoshop 및 Illustrator
# - Google Analytics
# - SEO 및 SEM 전략
#
# ---
#
# **언어**
#
# - 한국어: 모국어
# - 영어: 고급 (TOEIC 920점)
#
# ---
#
# **수상 및 인증**
#
# - 서울대학교 총장상 (2019년 우수 학업 성취 및 리더십)
# - Google Analytics 인증 (2021년)
# - 국제마케팅협회 주최 마케팅 아이디어 경진대회 우승 (2020년)
#
# ---
#
# **기타 활동**
#
# - **서울대학교 광고동아리**
#   회장
#   2018년 3월 – 2019년 2월
#   - 동아리 활동 총괄 및 외부 행사 기획
#   - 기업과의 협력 프로젝트 진행
#
# - **봉사활동**, 서울시 청소년 센터
#   멘토
#   2020년 3월 – 2020년 12월
#   - 고등학생 대상 진로 상담 및 학습 지도
#   - 비영리 봉사활동 기획 및 실행
#
# ---
#
# **개인적 성향 및 목표**
#
# 저는 창의적 사고와 분석적 능력을 바탕으로 디지털 마케팅에 강한 열정을 가지고 있습니다. 팀워크를 중요시하며 협업을 통해 더 나은 결과를 도출하는 것을 목표로 합니다. 앞으로도 끊임없는 학습과 성장을 통해 마케팅 전문가로서의 역량을 더욱 발전시키고자 합니다.
#
# (참고: 구체적인 정보를 남기지 않기 위해 일부 정보는 예시로 작성되었습니다.)
#
# [HUMAN]: 경력: 총 1년 7개월 중 1년차 마케팅 업무 2년차 현장 영업
#
# [AI]: [이름]
# [주소]
# [전화번호]
# [이메일]
#
# [개인 요약]
# 창의적이고 목표 지향적인 마케팅 및 영업 전문가로서 1년 7개월의 풍부한 경험을 바탕으로 고객 중심의 전략 개발과 실질적인 성과 달성에 기여해왔습니다. 빠르게 변화하는 시장 환경에 적응하고 협업을 통해 최상의 결과를 도출할 수 있는 능력을 갖추고 있습니다.
#
# [경력 요약]
#
# 1. 회사명 (2022년 - 현재)
#    - 직급: 현장 영업 관리자
#    - 주요 업무:
#      - 고객 요구 분석 및 요구사항에 맞춘 맞춤형 서비스 제공
#      - 월간 매출 목표 설정 및 달성을 위한 전략 수립
#      - 신속한 고객 문제 해결을 통해 고객 만족도 향상 및 유지
#      - 경쟁사 분석 및 시장 동향을 모니터링하여 판매 촉진 방안 마련
#
# 2. 회사명 (2021년 - 2022년)
#    - 직급: 마케팅 담당자
#    - 주요 업무:
#      - 제품 출시 및 프로모션 캠페인 기획 및 실행
#      - 디지털 마케팅 채널 관리 및 콘텐츠 생성
#      - 시장 조사 및 데이터 분석을 통한 고객 인사이트 도출
#      - 효과적인 브랜드 메시지 전달을 위한 커뮤니케이션 전략 개발
#
# [학력]
# 대학교명, 전공, 졸업년도
#
# [기술 및 자격증]
# - 데이터 분석 및 보고서 작성 능력
# - 디지털 마케팅 도구 및 소셜 미디어 플랫폼 활용 능력
# - CRM 소프트웨어 경험
#
# [기타 정보]
# - 뛰어난 대인 관계 기술로 팀의 협업을 촉진하고 긍정적인 업무 환경 조성에 기여
# - 고객과의 신뢰 구축을 통해 장기적 비즈니스 관계 유지를 이끌어냄
#
# [결론]
# 실무 경험과 강력한 커뮤니케이션 능력을 바탕으로 고객의 기대를 초과하는 결과를 창출하는 것을 목표로 하고 있습니다. 귀사의 비즈니스 성공에 기여할 기회를 기대합니다.
#
# [HUMAN]: 기술: 현재 교육기관에서 프리미어프로, 애프터이펙트, Python, LLM, Html 등 이수중
#
# [AI]: [이름]
# [주소]
# [전화번호]
# [이메일 주소]
#
# ---
#
# **경력 목표**
# 시각적 창의성과 기술적 역량을 결합하여 디지털 미디어 분야에서 혁신적인 콘텐츠를 개발하고자 하는 열정을 가진 인재로, 다양한 멀티미디어 도구와 프로그래밍 언어를 활용한 프로젝트에 참여하고 싶습니다.
#
# **기술 스킬**
#
# - **디지털 비디오 편집 & 이펙트 디자인**: 현재 교육기관에서 Adobe Premiere Pro와 After Effects 과정을 이수 중입니다. 이 두 소프트웨어에 대한 체계적인 학습을 통해 비디오 편집 및 모션 그래픽 디자인 능력을 향상시키고 있으며, 이를 통해 창의적이고 몰입감 있는 콘텐츠 제작에 기여할 수 있습니다.
#
# - **프로그래밍**: Python 언어를 배우면서 기본적인 프로그래밍 원리와 데이터 분석 기법을 익히고 있습니다. 이러한 지식을 통해 효율적인 워크플로우 자동화 및 데이터 기반의 프로젝트를 수행할 준비가 되어 있습니다.
#
# - **웹 개발**: HTML을 활용하여 웹 페이지 구조 설계 및 간단한 웹 애플리케이션 제작에 대한 이해를 높이고 있습니다. 이러한 웹 기술을 영상 및 애니메이션 콘텐츠와 결합하여 사용자 인터페이스를 개선할 수 있는 역량을 갖추고자 합니다.
#
# - **인공지능 및 머신러닝**: LLM(Large Language Model) 학습을 통해 최신 인공지능 기술 동향을 파악하고 있으며, 이를 통해 자연어 처리 및 생성 AI 프로젝트에 대한 관심과 이해도를 높이고 있습니다.
#
# **교육**
# [현재 교육기관 이름] - [시작 연도]부터 수강 중
# - Adobe Premiere Pro 및 After Effects 과정
# - Python 프로그래밍
# - HTML 웹 개발 기초
# - LLM을 활용한 인공지능 및 머신러닝 입문
#
# **프로젝트 및 성과**
# - 다양한 영상을 편집 및 이펙트 디자인하여 학습 프로젝트를 성공적으로 완수함.
# - Python을 사용하여 간단한 데이터 분석 프로젝트에 참여, 데이터 시각화 등의 기본적 역량을 증명함.
#
# **기타 스킬 및 활동**
# - 강한 문제 해결 능력과 창의성을 바탕으로 팀 프로젝트 및 과제에 기여.
# - 디지털 미디어와 기술의 융합에 지속적인 관심을 가지고 자기주도적인 학습 지속.
#
# **언어 능력**
# - 한국어: 모국어
# - 영어: 중급 (읽기 및 작문 능력)
#
# ---
#
# 본인은 현재 교육 과정에서 습득한 기술과 역량을 활용하여 귀사의 비전과 목표를 실현하는 데 기여할 수 있는 기회를 열망하고 있습니다. 감사합니다.
